# %% [markdown]
# # Baselines
# This notebook explores basic approaches to solving the task. They are simple to implement and can be used as a foundation for more complex solutions by comparing metrics with these baselines.
#
# We'll test three main ideas:
# * Recommend the user's last purchase
#     - Score: **0.32841** (mean) - 0.33932 (level = 1), 0.33752 (level = 2), 0.30838 (level = 3)
# * Find the most frequently purchased items for each user and recommend them
#     - Fixed basket size (k = 10) - Score: **0.32415** (mean) - 0.34320 (level = 1), 0.33291 (level = 2), 0.29633 (level = 3)
#     - Variable basket size - Score: **0.37277** (mean) - 0.38993 (level = 1), 0.38031 (level = 2), 0.34807 (level = 3)
# * Recommend the overall most popular items to each user
#     - Fixed basket size (k = 15) - Score: **0.37593** (mean) - 0.36759 (level = 1), 0.37293 (level = 2), 0.38727 (level = 3)
#     - Variable basket size - Score: **0.36432** (mean) - 0.37505 (level = 1), 0.38073 (level = 2), 0.33718 (level = 3)
#
# _The notebook can be run in "Run all" mode_

# %% [markdown]
# ## Loading Libraries

# %%
import pandas as pd
import numpy as np
from tqdm.auto import tqdm
from sklearn.metrics import f1_score

tqdm.pandas()

# %% [markdown]
# ## Data Preparation

# %% [markdown]
# ### Loading

# %%
df = pd.read_csv("data/main.csv")

# %%
df.rename(
    columns={"order_completed_at": "time"}, inplace=True
)  # rename column for convenience
df["time"] = pd.to_datetime(
    df["time"], format="%Y-%m-%d %H:%M:%S"
)  # change column type for further processing

# %% [markdown]
# ### Research

# %%
df.head()
# Out:
#    user_id                time  cart
# 0        2 2015-03-22 09:25:46   399
# 1        2 2015-03-22 09:25:46    14
# 2        2 2015-03-22 09:25:46   198
# 3        2 2015-03-22 09:25:46    88
# 4        2 2015-03-22 09:25:46   157

# %% [markdown]
# Users

# %%
df["user_id"].agg(["nunique", "min", "max"])
# Out:
# nunique    20000
# min            0
# max        19999
# Name: user_id, dtype: int64

# %% [markdown]
# Items

# %%
df["cart"].agg(["nunique", "min", "max"])
# Out:
# nunique    881
# min          0
# max        880
# Name: cart, dtype: int64

# %% [markdown]
# Purchase time

# %%
df["time"].describe(datetime_is_numeric=True)
# Out:
# count                          3123064
# mean     2020-04-09 01:17:00.182836992
# min                2015-03-22 09:25:46
# 25%                2020-02-03 06:03:43
# 50%                2020-05-19 06:35:20
# 75%                2020-07-14 04:50:22
# max                2020-09-03 23:45:45
# Name: time, dtype: object

# %% [markdown]
# Basket size

# %%
df.groupby("time")["cart"].count().hist(bins=50)
df.groupby("time")["cart"].count().describe()
# Out:
# count    208155.000000
# mean         15.003550
# std           8.892248
# min           1.000000
# 25%           9.000000
# 50%          14.000000
# 75%          20.000000
# max         120.000000
# Name: cart, dtype: float64

# %% [markdown]
# ### Creating dataset

# %%
# Replaces duplicate items in the basket with a single record indicating the quantity
def duplicates_to_count(t):
    return (
        t.groupby(["user_id", "time"])["cart"]
        .value_counts()
        .to_frame()
        .rename(columns={"cart": "count"})
        .reset_index()
    )


# Performs the reverse operation
def count_to_duplicates(t):
    g = t.copy()
    g["to_explode"] = g["count"].apply(lambda x: [i for i in range(x)])
    g = g.explode("to_explode").drop(columns=["count", "to_explode"])
    return g


# Creates all combinations of user_id (user) and cart (item) that the user has ever purchased
def make_skeleton(t):
    return (
        t.groupby("user_id")["cart"].unique().to_frame().reset_index().explode("cart")
    )


# Creates train dataset and its targets
# Targets are formed based on the last basket of each user
# level=1 means that the last purchase is used to form targets, level=2 - the second to last, and so on
def make_train_targets(t, level=1):
    user_last_time = t.groupby(["user_id"])["time"].max().to_frame().reset_index()
    user_last_time["last_buy"] = 1

    train = pd.merge(t, user_last_time, on=["time", "user_id"], how="left")
    train = train[train["last_buy"] != 1]
    train.drop(columns=["last_buy"], inplace=True)

    if level >= 2:
        return make_train_targets(train, level - 1)

    user_last_time.drop(columns=["last_buy"], inplace=True)

    user_last_carts = pd.merge(user_last_time, t, on=["user_id", "time"], how="left")

    skeleton = make_skeleton(t)
    targets = pd.merge(
        skeleton,
        user_last_carts.drop(columns=["time"]),
        on=["user_id", "cart"],
        how="left",
    )
    targets.fillna(0, inplace=True)
    targets["count"] = targets["count"].apply(lambda x: x if x <= 1 else 1).astype(int)
    targets.rename(columns={"count": "target"}, inplace=True)
    return train, targets

# %%
df = duplicates_to_count(df)

# %%
df.head()
# Out:
#    user_id                time  cart  count
# 0        0 2020-07-19 09:59:17    14      1
# 1        0 2020-07-19 09:59:17    20      1
# 2        0 2020-07-19 09:59:17    57      1
# 3        0 2020-07-19 09:59:17    82      1
# 4        0 2020-07-19 09:59:17   379      1

# %%
train, targets = make_train_targets(df, level=1)

# %%
train.head()
# Out:
#    user_id                time  cart  count
# 0        0 2020-07-19 09:59:17    14      1
# 1        0 2020-07-19 09:59:17    20      1
# 2        0 2020-07-19 09:59:17    57      1
# 3        0 2020-07-19 09:59:17    82      1
# 4        0 2020-07-19 09:59:17   379      1

# %%
targets.head()
# Out:
#    user_id  cart  target
# 0        0    14       0
# 1        0    20       0
# 2        0    57       1
# 3        0    82       0
# 4        0   379       0

# %% [markdown]
# ## Approaches

# %% [markdown]
# ### User's Last Basket
# Let's take the user's last basket and recommend all items from it as their next basket

# %%
def user_last_cart_baseline(t, skeleton):
    user_last_time = t.groupby(["user_id"])["time"].max().to_frame().reset_index()
    user_last_carts = pd.merge(user_last_time, t, on=["user_id", "time"], how="left")
    res = (
        pd.merge(
            skeleton,
            user_last_carts.drop(columns=["time"]),
            on=["user_id", "cart"],
            how="left",
        )
        .fillna(0)
        .rename(columns={"count": "predict"})
    )
    res["predict"] = (
        res["predict"].progress_apply(lambda x: x if x <= 1 else 1).astype(int)
    )
    return res

# %%
train_res = user_last_cart_baseline(train, targets)
# Out:
#   0%|          | 0/1117600 [00:00<?, ?it/s]

# %%
train_res.head()
# Out:
#    user_id  cart  target  predict
# 0        0    14       0        1
# 1        0    20       0        0
# 2        0    57       1        1
# 3        0    82       0        1
# 4        0   379       0        1

# %%
f1_score(train_res["target"], train_res["predict"])
# Out:
# 0.3393176623703617

# %% [markdown]
# ### Top Items for Each User

# %% [markdown]
# #### Fixed basket size

# %% [markdown]
# Let's take all known user baskets, create a personal top products list of fixed size for each user and recommend it

# %%
def user_top_k_personal_rec_baseline(t, skeleton, k=10):
    g = (
        count_to_duplicates(t)
        .groupby("user_id")["cart"]
        .value_counts()
        .to_frame()
        .rename(columns={"cart": "count"})
        .groupby("user_id")["count"]
        .head(k)
        .to_frame()
        .reset_index()
        .drop(columns=["count"])
    )
    g["predict"] = 1
    res = skeleton.copy()
    res = res.merge(g, how="left", on=["user_id", "cart"])
    res["predict"] = res["predict"].fillna(0).astype(int)

    return res

# %%
train_res = user_top_k_personal_rec_baseline(train, targets)

# %%
train_res.head()
# Out:
#    user_id  cart  target  predict
# 0        0    14       0        1
# 1        0    20       0        1
# 2        0    57       1        1
# 3        0    82       0        1
# 4        0   379       0        1

# %%
f1_score(train_res["target"], train_res["predict"])
# Out:
# 0.34319546434025816

# %% [markdown]
# #### Variable basket size

# %% [markdown]
# To avoid using a fixed basket size for all users, we can take the average or median number of items in the basket for each user. This provides a significant quality improvement.

# %%
def user_top_x_personal_rec_baseline(t, skeleton):
    users_cart_len = (
        t.groupby(["user_id", "time"])["count"]
        .sum()
        .reset_index()
        .groupby("user_id")["count"]
        .median()
        .round()
        .astype(int)
        .reset_index()
        .rename(columns={"count": "cart_len"})
    )

    g = (
        count_to_duplicates(t)
        .groupby("user_id")["cart"]
        .value_counts()
        .to_frame()
        .rename(columns={"cart": "count"})
        .reset_index()
    )
    g = pd.merge(g, users_cart_len, on="user_id", how="left")

    g = (
        g.groupby("user_id")
        .progress_apply(lambda x: x["cart"][: x["cart_len"].unique()[0]])
        .to_frame()
        .droplevel(level=1)
        .reset_index()
    )

    g["predict"] = 1
    res = skeleton.copy()
    res = res.merge(g, how="left", on=["user_id", "cart"])
    res["predict"] = res["predict"].fillna(0).astype(int)

    return res

# %%
train_res = user_top_x_personal_rec_baseline(train, targets)
# Out:
#   0%|          | 0/20000 [00:00<?, ?it/s]

# %%
f1_score(train_res["target"], train_res["predict"])
# Out:
# 0.38992994994398833

# %% [markdown]
# ### Top Popular Items

# %% [markdown]
# #### Fixed basket size

# %% [markdown]
# Let's take all known user baskets, create a general top of the most popular items and recommend it

# %%
def top_k_popular_baseline(t, skeleton, k=15):
    top_k_items = (
        t.groupby("cart")["count"]
        .sum()
        .to_frame()
        .reset_index()
        .sort_values("count", ascending=False)
        .head(k)["cart"]
        .tolist()
    )

    res = skeleton.copy()
    res["predict"] = np.where(res.cart.isin(top_k_items), 1, 0)

    return res

# %%
train_res = top_k_popular_baseline(train, targets)

# %%
f1_score(train_res["target"], train_res["predict"])
# Out:
# 0.36758787992167213

# %% [markdown]
# #### Variable basket size

# %% [markdown]
# We can also use a variable basket size for recommendations

# %%
def top_x_popular_baseline(t, skeleton):

    users_cart_len = (
        train.groupby(["user_id", "time"])["count"]
        .sum()
        .reset_index()
        .groupby("user_id")["count"]
        .median()
        .round()
        .astype(int)
        .reset_index()
        .rename(columns={"count": "cart_len"})
    )

    top_x_max_items = (
        t.groupby("cart")["count"]
        .sum()
        .to_frame()
        .reset_index()
        .sort_values("count", ascending=False)["cart"]
        .tolist()[: users_cart_len["cart_len"].max()]
    )

    users_cart_len["cart"] = users_cart_len["cart_len"].apply(
        lambda x: top_x_max_items[:x]
    )
    users_top_x = users_cart_len.drop(columns=["cart_len"]).explode("cart")
    users_top_x["predict"] = 1

    res = skeleton.copy()
    res = res.merge(users_top_x, how="left", on=["user_id", "cart"])
    res["predict"] = res["predict"].fillna(0).astype(int)

    return res

# %%
train_res = top_x_popular_baseline(train, targets)

# %%
f1_score(train_res["target"], train_res["predict"])
# Out:
# 0.37505094485043405
